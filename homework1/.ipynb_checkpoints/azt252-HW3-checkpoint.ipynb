# %% [markdown]
# BEGIN
#
# Alright, so the objective is to do sin(x) in taylor and put that in a function that can vary based on terms (basically "n")
#
# Then, do it for n = 1, 2, 3, 4. I then have to use another function that will space out sin(x) from 0 to 10, however I feel like there a numpy function like that, I think it was linspace, I have used it but I always get errors. I will search up how to deal with it a bit of assistance from online sources.
#
# Then calculate exact sin and basically do the same thing as CH3, (Read: I will probably heavily reference that code and if not just copy the structure if no change is needed)
#
# PLOTTTTT
# so with plotting imma do what I did before and add lists
#
# and yeah that's it I think

# %%
import numpy as np
import math


def sinTaylor(numTerm, x):
    sumTaylor = 0
    for i in range(0, numTerm):
        factorialNum = 2*i + 1
        calcTaylor = ((-1)**i)*(x**(2*i + 1))/(math.factorial(factorialNum))
        sumTaylor += calcTaylor #fancy add operator woahhh
    return sumTaylor


print(sinTaylor(4, 10))
print(np.sin(0.2))
# Out:
# -1307.4603174603174
# 0.19866933079506122

# %% [markdown]
# Okay, for future reference, if there is a summation that has sigma, always put the n for number of terms AND ANY OTHER VARIABLES SUCH AS "x." If not, program will be awful.
#
# So, in general, for sigmaSums you need (n, x1,...xn), with xn being basically the number of variables.
#
# Now for next piece of code I want to create a list (linspace) so that it could plot it. Not only that, but I think imma make a function so that the "x" in sinTaylor can be linspaced. Here goes

# %%
sinTList = np.arange(0, 10.1, 0.1) #I could put this in a new def
sinTErrorList = []

def sinTaylorCompDistr(start, end, step, nSample):
    trueEnd = end + step #needed to add this cuz the end in arange is a step less
    xValues = np.arange(start, trueEnd, step)
    sinTValues = []
    for x in xValues:
        calcSinT = sinTaylor(nSample, x) 
        sinTValues.append(calcSinT)#Read: DO NOT JUST APPEND THE FUNCTION, IT CAUSES MONSTERS, MAKE A VARIABLE FOR FUNC RESULT
    return sinTValues

print(sinTaylorCompDistr(0, 10, 0.1, 1))
print(sinTaylorCompDistr(0, 10, 0.1, 2))
print(sinTaylorCompDistr(0, 10, 0.1, 3))
print(sinTaylorCompDistr(0, 10, 0.1, 4))

def sinNumPyDistr(start, end, step):
    trueEnd = end + step
    xValues = np.arange(start, trueEnd, step)
    sinNPValues = []
    for x in xValues:
        calcSinNP = np.sin(x)
        sinNPValues.append(calcSinNP)
    return sinNPValues

sinNumPyDistr(0, 10, 0.1)
# Out:
# [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5, 0.6000000000000001, 0.7000000000000001, 0.8, 0.9, 1.0, 1.1, 1.2000000000000002, 1.3, 1.4000000000000001, 1.5, 1.6, 1.7000000000000002, 1.8, 1.9000000000000001, 2.0, 2.1, 2.2, 2.3000000000000003, 2.4000000000000004, 2.5, 2.6, 2.7, 2.8000000000000003, 2.9000000000000004, 3.0, 3.1, 3.2, 3.3000000000000003, 3.4000000000000004, 3.5, 3.6, 3.7, 3.8000000000000003, 3.9000000000000004, 4.0, 4.1000000000000005, 4.2, 4.3, 4.4, 4.5, 4.6000000000000005, 4.7, 4.800000000000001, 4.9, 5.0, 5.1000000000000005, 5.2, 5.300000000000001, 5.4, 5.5, 5.6000000000000005, 5.7, 5.800000000000001, 5.9, 6.0, 6.1000000000000005, 6.2, 6.300000000000001, 6.4, 6.5, 6.6000000000000005, 6.7, 6.800000000000001, 6.9, 7.0, 7.1000000000000005, 7.2, 7.300000000000001, 7.4, 7.5, 7.6000000000000005, 7.7, 7.800000000000001, 7.9, 8.0, 8.1, 8.200000000000001, 8.3, 8.4, 8.5, 8.6, 8.700000000000001, 8.8, 8.9, 9.0, 9.1, 9.200000000000001, 9.3, 9.4, 9.5, 9.600000000000001, 9.700000000000001, 9.8, 9.9, 10.0]
# [0.0, 0.09983333333333334, 0.19866666666666669, 0.29550000000000004, 0.38933333333333336, 0.4791666666666667, 0.5640000000000001, 0.6428333333333334, 0.7146666666666667, 0.7785, 0.8333333333333334, 0.8781666666666667, 0.912, 0.9338333333333333, 0.9426666666666668, 0.9375, 0.9173333333333332, 0.8811666666666667, 0.828, 0.7568333333333332, 0.6666666666666667, 0.5565, 0.4253333333333329, 0.2721666666666662, 0.0959999999999992, -0.10416666666666652, -0.3293333333333335, -0.5805000000000002, -0.8586666666666671, -1.164833333333335, -1.5, -1.8651666666666675, -2.2613333333333347, -2.689500000000002, -3.150666666666668, -3.645833333333333, -4.176, -4.742166666666667, -5.345333333333334, -5.986500000000003, -6.666666666666666, -7.386833333333336,
#  -0.6312666378723208,
#  -0.5506855425976376,
#  -0.4646021794137566,
#  -0.373876664830236,
#  -0.27941549819892586,
#  -0.18216250427209502,
#  -0.0830894028174964,
#  0.0168139004843506,
#  0.11654920485049364,
#  0.21511998808781552,
#  0.3115413635133787,
#  0.4048499206165983,
#  0.49411335113860894,
#  0.5784397643882001,
#  0.6569865987187891,
#  0.7289690401258765,
#  0.7936678638491531,
#  0.8504366206285648,
#  0.8987080958116269,
#  0.9379999767747389,
#  0.9679196720314865,
#  0.9881682338770004,
#  0.998543345374605,
#  0.998941341839772,
#  0.9893582466233818,
#  0.9698898108450863,
#  0.9407305566797726,
#  0.9021718337562933,
#  0.8545989080882804,
#  0.7984871126234903,
#  0.7343970978741133,
#  0.662969230082182,
#  0.5849171928917617,
#  0.5010208564578846,
#  0.4121184852417566,
#  0.3190983623493521,
#  0.22288991410024592,
#  0.1244544235070617,
#  0.024775425453357765,
#  -0.0751511204618093,
#  -0.1743267812229814,
#  -0.2717606264109442,
#  -0.3664791292519284,
#  -0.45753589377532133,
#  -0.5440211108893698]

# %% [markdown]
# That was quite a trip, I created monsters and destroyed, but I made it. Here's what I learned: If you want steps, do arange, b/c linspace really does not like steps, only sample. NEVER APPEND FUNCTIONS. Now, onto the main course of plotting which will basically just be a function that combines both of these without needing to use those two function (Read: I didn't realize this until too late)

# %%
import matplotlib.pyplot as plt


def plottingSinTError(start, end, step, nSample,):
    trueEnd = end + step
    xLine = np.arange(start, trueEnd, step)
    errorValues = []
    for x in xLine:
        calcSinNP = np.sin(x)
        calcSinT = sinTaylor(nSample, x)
        absError = abs(calcSinT - calcSinNP)
        errorValues.append(absError)
    return xLine, errorValues

xAxis, yAxis = plottingSinTError(0, 10, 0.1, 1)

plt.plot(xAxis, yAxis)
plt.xlabel("X Values")
plt.ylabel("Absolute Error")
plt.show()

# %% [markdown]
# LETSSS GOOOO IT WORKEDDD, alright, now time to make it kinda nice by using subplots

# %%
plt.subplot(2, 2, 1)
xAxis, yAxis = plottingSinTError(0, 10, 0.1, 1)

plt.plot(xAxis, yAxis)
plt.xlabel("X Values")
plt.ylabel("Absolute Error")
plt.show()

plt.subplot(2, 2, 2)
xAxis, yAxis = plottingSinTError(0, 10, 0.1, 2)

plt.plot(xAxis, yAxis)
plt.xlabel("X Values")
plt.ylabel("Absolute Error")
plt.show()

plt.subplot(2, 2, 3)
xAxis, yAxis = plottingSinTError(0, 10, 0.1, 3)

plt.plot(xAxis, yAxis)
plt.xlabel("X Values")
plt.ylabel("Absolute Error")
plt.show()

plt.subplot(2, 2, 4)
xAxis, yAxis = plottingSinTError(0, 10, 0.1, 4)

plt.plot(xAxis, yAxis)
plt.xlabel("X Values")
plt.ylabel("Absolute Error")
plt.show()

# %% [markdown]
# Nice! I could prob make the subplot thing into a function, but I don't find it necessary yet. Either way, this was nice in for learning how some things worked and looking at some documentation from Stack Overflow. At the end of this course, though, I think I am gonna be Dr. Frankenstein. Until next time! (Read: I want chicken wings)
#
# END
