# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate some sample data
# Creating data points that roughly follow a quadratic curve
np.random.seed(0)
x = np.linspace(-5, 5, 50) # 50 points between -5 and 5
y = 2 * x**2 + 3 * x + np.random.randn(50) * 10 # y = 2x^2 + 3x + some noise

# Step 2: Polynomial fitting using NumPy's polyfit
# Fit a 2nd degree polynomial to the data
degree = 2 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)

# Step 4: Plotting the results
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Polynomial Coefficients:  [2.09218103 1.58837751 0.60606342]

# %%
# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 108.8860
# R-squared: 0.7236

# %%
#Part A:
import random

def randomizeXY(N):
    randomX = []
    randomY = []
    for i in range(N):
        numXRand = random.uniform(0, 1)
        randomX.append(numXRand)
        numYRand = random.uniform(0, 1)
        randomY.append(numYRand)
        
    randomX.sort()
    return np.array(randomX), np.array(randomY) #Note: if you wanna do funky stuff with arrays, always use np

X, Y = randomizeXY(5)

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

y_pred = m*X + c
plt.scatter(X, Y)
plt.plot(X, m*X + c)
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')

#--------------------------------------------------------------------------------------------------------------------------

degree = 3 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')

# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

print(X)
print(Y)
# Out:
# Slope: -0.24163713802444917, Intercept: 0.9106272431526086
# Mean Squared Error: 0.0041
# R-squared: 0.4748
# Polynomial Coefficients:  [-3.36213431  3.79274664 -1.30458979  0.98992014]
# Mean Squared Error: 0.0038
# R-squared: 0.5162
# [0.18339342 0.28907811 0.72135251 0.74089109 0.77325065]
# [0.85655533 0.85026788 0.68622452 0.84777183 0.65797155]

# %%
#Part B:

import random

def randomizeXY(N):
    randomX = []
    randomY = []
    for i in range(N):
        numXRand = random.uniform(0, 1)
        randomX.append(numXRand)
        numYRand = random.uniform(0, 1)
        randomY.append(numYRand)
        
    randomX.sort()
    return np.array(randomX), np.array(randomY) #Note: if you wanna do funky stuff with arrays, always use np

X, Y = randomizeXY(10)

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

y_pred = m*X + c
plt.scatter(X, Y)
plt.plot(X, m*X + c)
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')

#
degree = 2 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')

# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
# Out:
# Slope: 0.8422100141522466, Intercept: -0.04107648921561828
# Mean Squared Error: 0.0268
# R-squared: 0.6943
# Polynomial Coefficients:  [-0.54194203  1.39132255 -0.13327286]
# Mean Squared Error: 0.0257
# R-squared: 0.7067

# %% [markdown]
# Least Squares Method:
# Mean Squared Error: 0.0636
# R-squared: 0.0117
#
# Polyfit Method:
# 1st Degree: (UnderFit)
# Mean Squared Error: 0.0636
# R-squared: 0.0117
#
# 2nd Degree:
# Mean Squared Error: 0.0749
# R-squared: 0.2253
#
# 3rd Degree:
# Mean Squared Error: 0.0716
# R-squared: 0.1608
#
# 4th Degree:
# Mean Squared Error: 0.0304
# R-squared: 0.6262
#
# 5th Degree:
# Mean Squared Error: 0.0232
# R-squared: 0.7927
#
# 6th Degree:
# Mean Squared Error: 0.0096
# R-squared: 0.6793
#
# 7th Degree:
# Mean Squared Error: 0.0160
# R-squared: 0.7563
#
# 8th Degree:
# Mean Squared Error: 0.0176
# R-squared: 0.8288
#
# 9th Degree:
# Mean Squared Error: 0.0000
# R-squared: 1.0000
#
# 10th Degree: Overfit Warning from Python ("RankWarning: Polyfit may be poorly conditioned")
# Mean Squared Error: 0.0000
# R-squared: 1.0000

# %%
import numpy as np
# Example data points
x = np.array([1, 2, 3])
# Create Vandermonde matrix for a polynomial of degree 2
degree = 2
V = np.vander(x, N=degree+1, increasing=True)
print(V)
# Out:
# [[1 1 1]
#  [1 2 4]
#  [1 3 9]]

# %%
# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-2718d5aeacf0> in <module>
#       2 VT_V = np.dot(V.T, V)
#       3 # V.T * y
# ----> 4 VT_y = np.dot(V.T, y)
#       5 # Solve for a (coefficients)
#       6 coefficients = np.linalg.solve(VT_V, VT_y)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (3,3) and (50,) not aligned: 3 (dim 1) != 50 (dim 0)

# %%
#Part C:

X = [0.18339342, 0.28907811, 0.72135251, 0.74089109, 0.77325065]
Y = [0.85655533, 0.85026788, 0.68622452, 0.84777183, 0.65797155]

# Create Vandermonde matrix for a polynomial of degree 2
degree = 2
V = np.vander(X, N=degree+1, increasing=True)
print(V)


# V.T * V
VT_V = np.dot(V.T, V)
# V.T * y
VT_y = np.dot(V.T, Y)
# Solve for a (coefficients)
coefficients = np.linalg.solve(VT_V, VT_y)

# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')

# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
# Out:
# [[1.         0.18339342 0.03363315]
#  [1.         0.28907811 0.08356615]
#  [1.         0.72135251 0.52034944]
#  [1.         0.74089109 0.54891961]
#  [1.         0.77325065 0.59791657]]
# Mean Squared Error: 1.0190
# R-squared: -129.3908
