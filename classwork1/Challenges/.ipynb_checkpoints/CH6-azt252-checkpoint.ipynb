# %%
import numpy as np

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %% [markdown]
# Used the same code from Week6-1(Tue)+2(Thu) for code snippets

# %%
# Example usage
A = np.array([[4, -1, 0, 0],
[-1, 4, -1, 0],
[0, -1, 4, -1],
[0, 0, -1, 3]])
b = np.array([15, 10, 10, 10])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 4
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [4 4 4 4]
# Iterations: 3

# %%
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
# Example usage
A = np.array([[4, -1, 0, 0],
[-1, 4, -1, 0],
[0, -1, 4, -1],
[0, 0, -1, 3]])
b = np.array([15, 10, 10, 10])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# Solution: [4 4 4 4]
# Iterations: 2

# %% [markdown]
# Time for the challenge:
# Challenge 6a:

# %%
import time

A = np.array([[10, -1, 2, 0, 0],
[-1, 11, -1, 3, 0],
[2, -1, 10, -1, 0],
[0, 3, -1, 8, -2],
[0, 0, 0, -2, 9]])

b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterationsJ = 100
max_iterationsGS = 100

start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterationsJ)
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(elapsed_time)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# 0.0007685832679271698
# Solution: [1 2 2 3 4]
# Iterations: 1

# %%
A = np.array([[10, -1, 2, 0, 0],
              [-1, 11, -1, 3, 0],
              [2, -1, 10, -1, 0],
              [0, 3, -1, 8, -2],
              [0, 0, 0, -2, 9]])

b = np.array([14, 30, 26, 25, 37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterationsJ = 100
max_iterationsGS = 100

start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterationsGS)
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(elapsed_time)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# 0.0005399249494075775
# Solution: [1 2 2 3 4]
# Iterations: 2

# %% [markdown]
# The Guass_seidel is faster (0.00054 > 0.000768) but and it should require less iterations, however I think because of this specific array, it has 2 and Jacobi has 1.

# %% [markdown]
# Challenge 6b:

# %%
A = np.array([[1, 2, 3, 0, 0],
             [2, 1, 2, 3, 0],
             [3, 2, 1, 2, 3],
             [0, 3, 2, 1, 2],
             [0, 0, 3, 2, 1]])
b = np.array([14, 22, 33, 26, 22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterationsJ = 100
max_iterationsGS = 100

start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterationsJ)
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(elapsed_time)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")

start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterationsGS)
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print(elapsed_time)
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
# Out:
# 0.01099557988345623
# Solution: [-5976176488926883840 -4324294422220818432   125198747742650400
#  -4324294422220818432 -5976176488926883840]
# Iterations: 100
# 0.006587354466319084
# Solution: [-4667072227903264768 -5861557759596381184  5941495520527654912
#     32542205762157592   557173100602271744]
# Iterations: 100
# <ipython-input-127-576e7ced6c37>:9: RuntimeWarning: overflow encountered in long_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-129-eebc67aa7cf6>:8: RuntimeWarning: overflow encountered in long_scalars
#   s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
# <ipython-input-129-eebc67aa7cf6>:10: RuntimeWarning: overflow encountered in long_scalars
#   x_new[i] = (b[i] - s1 - s2) / A[i][i]

# %% [markdown]
# The methods do not converge, which I think is mostly due to it not being diagonally dominant
