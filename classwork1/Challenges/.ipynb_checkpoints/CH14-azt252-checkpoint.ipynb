# %% [markdown]
# Approximating Derivative of f(x)=sin⁡(x) with Forward Difference, Central Difference, Backwards Difference

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function and the domain
f = lambda x: np.sin(x)
a, b = 0, 2 * np.pi # Interval
N = 50 # Number of sample points
# Create a uniform grid
x = np.linspace(a, b, N)
y = f(x)

# Step size

h = (b - a) / (N - 1)

 

# Central Difference Approximation for the derivative

df_dxCentral = (f(x + h) - f(x - h)) / (2 * h)

# Forward Difference Approximation
### YOUR CODE HERE ###

df_dxForward = (f(x+h) - f(x))/h
 

# Backward Difference Approximation

df_dxBackward = (f(x) - f(x-h))/h
 

# Plot the approximation and the true derivative

plt.subplot(4, 1, 1)
plt.plot(x, df_dxForward, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Forward Difference")
plt.legend()


plt.subplot(4, 1, 2)
plt.plot(x, df_dxBackward, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Backward Difference")
plt.legend()

plt.subplot(4, 1, 3)
plt.plot(x, df_dxCentral, 'o--', label='Central Difference Approximation')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = sin(x) using Central Difference")
plt.legend()

plt.subplot(4, 1, 4)
plt.plot(x, np.cos(x), label='Exact Derivative')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.title("Approximating Derivative of f(x) = cos(x)")
plt.legend()
## Do a canvas of 4 subplots or 4 graphs on one plot comparing cos(x), Forward Difference, Backwards Difference, and Central Difference Methods

# %% [markdown]
# All of the derivatives are very approximate to the derivative of sin(x), which is cos(x)
