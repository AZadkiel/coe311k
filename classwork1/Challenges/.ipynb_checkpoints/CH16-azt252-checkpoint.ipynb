# %% [markdown]
# Accuracy: Euler’s Method is simple but can have significant errors for larger step sizes. The approximation can be improved by reducing the step size hhh, but this increases computational cost.
#
# Stability: For oscillatory problems (like a harmonic oscillator), stability depends on the step size. Using a step size that is too large can lead to numerical instability, where the solution oscillates erratically or diverges.
#
#
# Modify the Demo code, play with the value of h [.01, .02, .03. .05, .1, .2, .3, .5], plot them all on the same canvas
#
# when does it become unstable?
#
# Is it becoming unstable?
#
# Play with the value of K, what are you seeing?
#
# Set k = 10, h = .01
#
# Thoughts on whether Euler's Method can solve this with a larger h?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters

k = 1.0        # Constant in the equation (e.g., spring constant)
h = 0.01       # Step size
x_start = 0    # Start of the interval
x_end = 10     # End of the interval
y_0 = 1.0      # Initial condition for y
v_0 = 0.0      # Initial condition for dy/dx

# Create arrays to store x, y, and v values



x_values = np.arange(x_start, x_end + h, h)
y_values = np.zeros(len(x_values))
v_values = np.zeros(len(x_values))

 # Set initial conditions

y_values[0] = y_0
v_values[0] = v_0

 

# Euler's Method loop

for i in range(1, len(x_values)):
    # Current values
    x_n = x_values[i - 1]
    y_n = y_values[i - 1]
    v_n = v_values[i - 1]    

    # Update equations
    y_values[i] = y_n + h * v_n
    v_values[i] = v_n + h * (-k * y_n)
    

#Plot the results

plt.figure(figsize=(10, 5))
plt.plot(x_values, y_values, label='Position y(x)')
plt.plot(x_values, v_values, label='Velocity v(x)', linestyle='--')
plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters

k = 1.0 # Constant in the equation (e.g., spring constant)
h = 0.01       # Step size
x_start = 0    # Start of the interval
x_end = 10     # End of the interval
y_0 = 1.0      # Initial condition for y
v_0 = 0.0      # Initial condition for dy/dx

stepSizes = [.01, .02, .03, .05, .1, .2, .3, .5]

# Create arrays to store x, y, and v values


for h in stepSizes:
    x_values = np.arange(x_start, x_end + h, h)
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))

    # Set initial conditions

    y_values[0] = y_0
    v_values[0] = v_0

 

    # Euler's Method loop

    for i in range(1, len(x_values)):
        # Current values
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    

        # Update equations
        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-k * y_n)
    
    plt.plot(x_values, y_values, label= f'step size = {h}')
    plt.legend()
#Plot the results

plt.figure(figsize=(10, 5))
plt.plot(x_values, y_values, label='Position y(x)')
plt.plot(x_values, v_values, label='Velocity v(x)', linestyle='--')
plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# The function becomes noticeably unstable when the step size becomes 0.1. It is becoming unstable since the larger step size led to erratic oscillations. I am also seeing that when the K-value is changed, the function becomes more unstable the higher it is, however when it is closer to 0, it becomes much more stable.

# %%
# Define the parameters

k = 10.0        # Constant in the equation (e.g., spring constant)
h = 0.01       # Step size
x_start = 0    # Start of the interval
x_end = 10     # End of the interval
y_0 = 1.0      # Initial condition for y
v_0 = 0.0      # Initial condition for dy/dx

# Create arrays to store x, y, and v values



x_values = np.arange(x_start, x_end + h, h)
y_values = np.zeros(len(x_values))
v_values = np.zeros(len(x_values))

 # Set initial conditions

y_values[0] = y_0
v_values[0] = v_0

 

# Euler's Method loop

for i in range(1, len(x_values)):
    # Current values
    x_n = x_values[i - 1]
    y_n = y_values[i - 1]
    v_n = v_values[i - 1]    

    # Update equations
    y_values[i] = y_n + h * v_n
    v_values[i] = v_n + h * (-k * y_n)
    

#Plot the results

plt.figure(figsize=(10, 5))
plt.plot(x_values, y_values, label='Position y(x)')
plt.plot(x_values, v_values, label='Velocity v(x)', linestyle='--')
plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# The higher K value led to a much more unstable function, meaning that euler's method requires a much smaller step size in order to maintain being stable.
