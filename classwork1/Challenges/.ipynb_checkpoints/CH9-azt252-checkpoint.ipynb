# %%
import numpy as np
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %% [markdown]
# Imported the code from the powerpoint slides

# %%
import matplotlib.pyplot as plt

plt.scatter(X, Y)
plt.plot(X, m*X + c)

# %% [markdown]
# The result above is for part 1.

# %%
import random

def randomizeXY(N):
    randomX = []
    randomY = []
    for i in range(N):
        numXRand = random.uniform(0, 1)
        randomX.append(numXRand)
        numYRand = random.uniform(0, 1)
        randomY.append(numYRand)
        
    randomX.sort()
    return np.array(randomX), np.array(randomY) #Note: if you wanna do funky stuff with arrays, always use np

X, Y = randomizeXY(5)

print(X)
print(Y)


# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")

plt.scatter(X, Y)
plt.plot(X, m*X + c)
# Out:
# [0.18838117 0.24899008 0.29361414 0.41047111 0.94079831]
# [0.67288762 0.33222009 0.29348257 0.3885278  0.07004441]
# Slope: -0.5693917432757962, Intercept: 0.5885562388691645

# %% [markdown]
# The result above is for part 2. The least squares function in python does not fit well with random points of data.

# %%
xAxis = np.arange(0, 1.01, 0.01)
mRand = random.uniform(0, 1)
bRand = random.uniform(0, 1)
randomNumber = random.uniform(0, 1)
def negPos():
    randomNum = random.uniform(0,1)
    if randomNum > 0.5:
        return 1
    else:
        return -1

yAxis = mRand*xAxis + bRand + (negPos()*randomNumber)

# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([xAxis, np.ones(len(xAxis))]).T
# Solve using least squares
m, c = np.linalg.lstsq(A, yAxis, rcond=None)[0]

yCalc = m*xAxis + c
residuals = abs(yAxis - yCalc)

maxError = max(residuals)
minError = min(residuals)

plt.scatter(xAxis, yAxis)
plt.plot(xAxis, yCalc)

print(f"Original Equation: y = {mRand}x + {bRand} ")
print(f"Calculated Equation: y = {m}x + {c} ")
print(maxError)
print(minError)

idx_max = np.argmax(residuals) #argmax finds the index with largest value
idx_min = np.argmin(residuals) #argmin finds the index with lowest value
print(f"Largest Residual: {maxError} at xAxis={xAxis[idx_max]}")
print(f"Smallest Residual: {minError} at xAxis={xAxis[idx_min]}")
# Out:
# Original Equation: y = 0.537720778071628x + 0.6177122303867654
# Calculated Equation: y = 0.5377207780716275x + 1.3919085777897195
# 8.881784197001252e-16
# 0.0
# Largest Residual: 8.881784197001252e-16 at xAxis=0.88
# Smallest Residual: 0.0 at xAxis=0.01

# %% [markdown]
# The result above is for part 3
