# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x), 'b')

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x), 'r')

plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x), 'g')

plt.subplot(2, 2, 4)
plt.plot(x, np.arcsin(x),'k')
plt.show()
# Out:
# <ipython-input-41-f5bb6b36e2a8>:11: RuntimeWarning: invalid value encountered in arcsin
#   plt.plot(x, np.arcsin(x),'k')
