# %%
import numpy as np

def BinaryReader(x):
    binaryList = []
    
    while x > 0:
        number = x % 2
        binaryList.append(number)
        x = x // 2
        binaryList.reverse()
    return binaryList.rever

BinaryReader(2025)
