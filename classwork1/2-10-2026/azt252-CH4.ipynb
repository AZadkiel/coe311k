# %%
for i in range(0,55):
    print(i, i+2**(-i))
# Out:
# 0 1
# 1 1.5
# 2 2.25
# 3 3.125
# 4 4.0625
# 5 5.03125
# 6 6.015625
# 7 7.0078125
# 8 8.00390625
# 9 9.001953125
# 10 10.0009765625
# 11 11.00048828125
# 12 12.000244140625
# 13 13.0001220703125
# 14 14.00006103515625
# 15 15.000030517578125
# 16 16.000015258789062
# 17 17.00000762939453
# 18 18.000003814697266
# 19 19.000001907348633
# 20 20.000000953674316
# 21 21.000000476837158
# 22 22.00000023841858
# 23 23.00000011920929
# 24 24.000000059604645
# 25 25.000000029802322
# 26 26.00000001490116
# 27 27.00000000745058
# 28 28.00000000372529
# 29 29.000000001862645
# 30 30.000000000931323
# 31 31.00000000046566
# 32 32.00000000023283
# 33 33.000000000116415
# 34 34.00000000005821
# 35 35.000000000029104
# 36 36.00000000001455
# 37 37.000000000007276
# 38 38.00000000000364
# 39 39.00000000000182
# 40 40.00000000000091
# 41 41.000000000000455
# 42 42.00000000000023
# 43 43.000000000000114
# 44 44.00000000000006
# 45 45.00000000000003
# 46 46.000000000000014
# 47 47.00000000000001
# ...

# %%
import numpy

def leibFunc(x):
    leibSum = 0
    for i in range(0, x):
        leibCurrent = (((-1)**i)/(2*i + 1))
        leibSum = leibCurrent + leibSum
        if (i%100 == 0):
            print(abs((4*leibSum) - numpy.pi)/(numpy.pi))
            
leibFunc(5000)
# Out:
# 0.2732395447351627
# 0.00315150580387468
# 0.0015836214753932633
# 0.001057505009525431
# 0.000793789005751022
# 0.0006353484414075896
# 0.0005296333874729713
# 0.00045407949250305123
# 0.0003973904646130839
# 0.00035328500350548475
# 0.0003179918149508013
# 0.00028910973709111743
# 0.0002650373280719025
# 0.00024466551819292626
# 0.0002272018883944259
# 0.00021206519044809295
# 0.00019881939733771412
# 0.00018713101627287207
# 0.000176740622792398
# 0.0001674433793591898
# 0.00015907539545632673
# 0.00015150398293974264
# 0.00014462056781363417
# 0.00013833545030563822
# 0.0001325738743772192
# 0.00012727304016872125
# 0.00012237980562142684
# 0.00011784889865893333
# 0.00011364151233219226
# 0.00010972419053097714
# 0.00010606793647030701
# 0.00010264749368209822
# 9.944076176776648e-05
# 9.642831835280076e-05
# 9.359302537720791e-05
# 9.091970285513445e-05
# 8.839485699879063e-05
# 8.600645241284703e-05
# 8.374372025298852e-05
# 8.159699588842421e-05
# 7.955758090949406e-05
# ...
