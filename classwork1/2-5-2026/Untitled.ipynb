# %%
import random
import matplot

# %%
for i in range (0,100):
    calculatedPi = monteCarloPi(100)
    truePi = numpy.pi
    true_error = abs(truePi - calculatedPi)
    relative_error = math.abs(truePi - calculatedPi/truePi)
    
    print(calculatedPi, true_error, relative_error)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-44a68420cfca> in <module>
#       1 for i in range (0,100):
# ----> 2     calculatedPi = monteCarloPi(100)
#       3     truePi = numpy.pi
#       4     true_error = abs(calculatedPi - truePi)
#
# NameError: name 'monteCarloPi' is not defined
